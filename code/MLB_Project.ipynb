# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

data = pd.read_csv('MLB_Data(Worksheet).csv')
data_velo = pd.read_csv('savant_data.csv')

# %%
print(data)
# Out:
#     Year     H    HR    SO     BA     TB   ERA
# 0   2025  8.26  1.16  8.36  0.245  13.60  4.15
# 1   2024  8.20  1.12  8.48  0.243  13.45  4.07
# 2   2023  8.40  1.21  8.61  0.248  14.01  4.33
# 3   2022  8.16  1.07  8.40  0.243  13.28  3.96
# 4   2021  8.13  1.22  8.68  0.244  13.69  4.26
# 5   2020  8.04  1.28  8.68  0.245  13.73  4.44
# 6   2019  8.65  1.39  8.81  0.252  14.92  4.49
# 7   2018  8.44  1.15  8.48  0.248  13.93  4.14
# 8   2017  8.69  1.26  8.25  0.255  14.51  4.35
# 9   2016  8.71  1.16  8.03  0.255  14.23  4.18
# 10  2015  8.67  1.01  7.71  0.254  13.78  3.95
# 11  2014  8.56  0.86  7.70  0.251  13.17  3.74
# 12  2013  8.66  0.96  7.55  0.253  13.54  3.86
# 13  2012  8.65  1.02  7.50  0.255  13.78  4.01
# 14  2011  8.70  0.94  7.10  0.255  13.61  3.94
# 15  2010  8.76  0.95  7.06  0.257  13.71  4.07
# 16  2009  8.96  1.04  6.91  0.262  14.26  4.31
# 17  2008  9.06  1.00  6.77  0.264  14.29  4.32
# 18  2007  9.25  1.02  6.62  0.268  14.59  4.46
# ...

# %%
data_velo = data_velo.rename(columns = {'year':'Year'})
print(data_velo)
# Out:
#     Year  velocity
# 0   2025      94.5
# 1   2024      94.3
# 2   2023      94.2
# 3   2022      93.9
# 4   2021      93.7
# 5   2020      93.4
# 6   2019      93.4
# 7   2018      93.1
# 8   2017      93.2
# 9   2016      93.2
# 10  2015      93.1
# 11  2014      92.8
# 12  2013      92.7
# 13  2012      92.5
# 14  2011      92.4
# 15  2010      92.2
# 16  2009      92.1
# 17  2008      91.9

# %%
bar = sns.catplot(data=data_velo, aspect=3, x="Year",y="velocity",kind="bar" , color="blue")
bar.set(ylim=(91, 95))
bar.fig.suptitle("Pitch Velocity Over The Years(MPH)")
# Out:
# Text(0.5, 0.98, 'Pitch Velocity Over The Years(MPH)')

# %%
plt.figure()
plt.plot(data["Year"], data["BA"], linewidth=2)
plt.ylabel("Batting Average")
plt.title("MLB Batting Average Over Time")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(data["Year"], data["SO"], linewidth=2)
plt.ylabel("Strike Outs")
plt.title("MLB Stikeouts Per Game")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data[["BA", "SO","ERA","TB"]].corr()
plt.figure()
sns.heatmap(correlation, annot=True, cmap="coolwarm",)
plt.title("Correlation Analysis")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
merged = pd.merge(data_velo, data, on="Year", how="inner")

plt.figure()
plt.scatter(merged['velocity'], merged['BA'])
plt.xlabel("Average Pitch Velocity(MPH)")
plt.ylabel("Batting Average")
plt.title("Batting Average VS Pitch Velocity(2008-2025)")
plt.grid(True)
plt.show()
